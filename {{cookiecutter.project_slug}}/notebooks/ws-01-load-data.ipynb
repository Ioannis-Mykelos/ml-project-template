# %% [markdown]
# # My first notebook to start the project

# %% [markdown]
# ### Imports

# %%
import sys
import os
from pathlib import Path
# import mlflow
import pandas as pd
from dotenv import load_dotenv
load_dotenv() # loads .env file into environment

  
# Go up one level from /notebooks to the root
# Project root should be in sys.path so we can import from src/
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# Go up one level from /notebooks to the root
# Project root should be in sys.path so we can import from src/
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# Fix the file path to the data file using pathlib
root = Path().resolve().parent # go up from notebooks/
file_path = root / os.getenv("INPUT_DATA_PATH_PREPROCESSING")

if file_path is None:
    raise ValueError("INPUT_DATA_PATH_PREPROCESSING environment variable is not set")
the_data = (
pd.read_parquet(path=file_path)
if file_path.suffix == ".parquet"
else pd.read_csv(filepath_or_buffer=file_path, engine="python")
)
print("Data loaded ✓")
